# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (20,10)

# %%
dataset = np.load('dataset.npz')
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = dataset['x_train'], dataset['y_train'], \
    dataset['x_test'], dataset['y_test']
    
feature_count = X_train_orig.shape[1]
target_count = Y_train_orig.shape[1]  

def normalize(X):
    return (X.astype('float32') - 120) / (X.shape[1] - 120)

#X_train_orig = normalize(X_train_orig)
#X_test_orig = normalize(X_test_orig)
    
for d in [X_train_orig, X_test_orig, Y_train_orig, Y_test_orig]:
    print(d.shape)
# Out:
# (75431, 12)
# (11777, 12)
# (75431, 1)
# (11777, 1)

# %%
print(X_train_orig[103,:])
print(Y_train_orig[103,:])
# Out:
# [1.         0.75292253 0.60076796 0.75624959 0.64157628 0.42705989
#  0.33976427 0.39605928 0.71423682 0.64898341 0.52917334 0.55906372]
# [6.]

# %%
plt.plot(Y_train_orig[1000:3000,:])

# %%
plt.imshow(X_train_orig[1000:3000,:].T)
